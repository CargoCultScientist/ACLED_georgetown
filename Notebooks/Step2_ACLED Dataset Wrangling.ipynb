# %% [markdown]
# # ACLED Dataset Cleaning and Initial Exploration

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
# %matplotlib inline
plt.rcParams["figure.dpi"] = 36

# %%
url = 'https://raw.githubusercontent.com/georgetown-analytics/ACLED/main/CSV_Main/step1_ACLED_Dataset_END.csv'
df = pd.read_csv(url, index_col=0)

# %%
df
# Out:
#                               country                  event_type  \
# data_id
# 8166147  Democratic Republic of Congo                     Battles
# 8166148                         Sudan  Violence against civilians
# 8166410                       Lesotho                       Riots
# 8166411                       Lesotho                       Riots
# 8059405                        Uganda  Violence against civilians
# ...                               ...                         ...
# 7121647                       Nigeria                       Riots
# 7966971                       Tunisia                    Protests
# 7121659                       Somalia                     Battles
# 7518716                  South Africa                    Protests
# 7518717                  South Africa                       Riots
#
#                 sub_event_type  fatalities  \
# data_id
# 8166147            Armed clash           0
# 8166148                 Attack           5
# 8166410  Violent demonstration           0
# 8166411  Violent demonstration           0
# 8059405                 Attack           2
# ...                        ...         ...
# 7121647           Mob violence           0
# 7966971       Peaceful protest           0
# 7121659            Armed clash           0
# 7518716       Peaceful protest           0
# 7518717  Violent demonstration           0
#
#                                                      notes
# data_id
# 8166147  On 1 June 2021, the ADF attacked a military ba...
# 8166148  On 1 June 2021, three masked gunmen opened fir...
# 8166410  On 1 June 2021, workers pelted stones and loot...
# 8166411  On 1 June 2021, workers set tires on fire and ...
# 8059405  On 1 June 2021, an unidentified armed group at...
# ...                                                    ...
# 7121647  On 1 June 2020, PDP supporters attacked APC su...
# 7966971  On 1 June 2020, aligned health workers protest...
# 7121659  On 1 June 2020, Al shabaab militants launched ...
# 7518716  On 1 June 2020, about 30 parents demonstrated ...
# 7518717  On 1 June 2020, about 300 demonstrators, mostl...
#
# [33378 rows x 5 columns]

# %%
import nltk
from string import digits
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.stem import PorterStemmer
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer
ps = PorterStemmer()

# %%
#making all text in notes column lowercase
df["notes"]=df["notes"].str.lower()
df
# Out:
#                               country                  event_type  \
# data_id
# 8166147  Democratic Republic of Congo                     Battles
# 8166148                         Sudan  Violence against civilians
# 8166410                       Lesotho                       Riots
# 8166411                       Lesotho                       Riots
# 8059405                        Uganda  Violence against civilians
# ...                               ...                         ...
# 7121647                       Nigeria                       Riots
# 7966971                       Tunisia                    Protests
# 7121659                       Somalia                     Battles
# 7518716                  South Africa                    Protests
# 7518717                  South Africa                       Riots
#
#                 sub_event_type  fatalities  \
# data_id
# 8166147            Armed clash           0
# 8166148                 Attack           5
# 8166410  Violent demonstration           0
# 8166411  Violent demonstration           0
# 8059405                 Attack           2
# ...                        ...         ...
# 7121647           Mob violence           0
# 7966971       Peaceful protest           0
# 7121659            Armed clash           0
# 7518716       Peaceful protest           0
# 7518717  Violent demonstration           0
#
#                                                      notes
# data_id
# 8166147  on 1 june 2021, the adf attacked a military ba...
# 8166148  on 1 june 2021, three masked gunmen opened fir...
# 8166410  on 1 june 2021, workers pelted stones and loot...
# 8166411  on 1 june 2021, workers set tires on fire and ...
# 8059405  on 1 june 2021, an unidentified armed group at...
# ...                                                    ...
# 7121647  on 1 june 2020, pdp supporters attacked apc su...
# 7966971  on 1 june 2020, aligned health workers protest...
# 7121659  on 1 june 2020, al shabaab militants launched ...
# 7518716  on 1 june 2020, about 30 parents demonstrated ...
# 7518717  on 1 june 2020, about 300 demonstrators, mostl...
#
# [33378 rows x 5 columns]

# %%
'''
removing numbers (dates) -- still need to remove months...
'''
def remove_num(list):
    pattern = '[0-9]'
    list = [re.sub(pattern, '', i) for i in list]
    return list

# %%
df["notes"] = remove_num(df["notes"])

# %%
df
# Out:
#                               country                  event_type  \
# data_id
# 8166147  Democratic Republic of Congo                     Battles
# 8166148                         Sudan  Violence against civilians
# 8166410                       Lesotho                       Riots
# 8166411                       Lesotho                       Riots
# 8059405                        Uganda  Violence against civilians
# ...                               ...                         ...
# 7121647                       Nigeria                       Riots
# 7966971                       Tunisia                    Protests
# 7121659                       Somalia                     Battles
# 7518716                  South Africa                    Protests
# 7518717                  South Africa                       Riots
#
#                 sub_event_type  fatalities  \
# data_id
# 8166147            Armed clash           0
# 8166148                 Attack           5
# 8166410  Violent demonstration           0
# 8166411  Violent demonstration           0
# 8059405                 Attack           2
# ...                        ...         ...
# 7121647           Mob violence           0
# 7966971       Peaceful protest           0
# 7121659            Armed clash           0
# 7518716       Peaceful protest           0
# 7518717  Violent demonstration           0
#
#                                                      notes
# data_id
# 8166147  on  june , the adf attacked a military base in...
# 8166148  on  june , three masked gunmen opened fire aga...
# 8166410  on  june , workers pelted stones and looted sh...
# 8166411  on  june , workers set tires on fire and block...
# 8059405  on  june , an unidentified armed group attacke...
# ...                                                    ...
# 7121647  on  june , pdp supporters attacked apc support...
# 7966971  on  june , aligned health workers protested in...
# 7121659  on  june , al shabaab militants launched an at...
# 7518716  on  june , about  parents demonstrated outside...
# 7518717  on  june , about  demonstrators, mostly women,...
#
# [33378 rows x 5 columns]

# %%
tokenizer = RegexpTokenizer(r'\w+')
df["notes"] = df["notes"].apply(lambda x: tokenizer.tokenize(x.lower()))
df["notes"]

# %%
lemmatizer = WordNetLemmatizer()

def word_lemmatizer(text):
    lem_text = [lemmatizer.lemmatize(i) for i in text]
    return lem_text

# %%
df["notes"] = df["notes"].apply(lambda x: word_lemmatizer(x))
df
# Out:
#                               country                  event_type  \
# data_id
# 8166147  Democratic Republic of Congo                     Battles
# 8166148                         Sudan  Violence against civilians
# 8166410                       Lesotho                       Riots
# 8166411                       Lesotho                       Riots
# 8059405                        Uganda  Violence against civilians
# ...                               ...                         ...
# 7121647                       Nigeria                       Riots
# 7966971                       Tunisia                    Protests
# 7121659                       Somalia                     Battles
# 7518716                  South Africa                    Protests
# 7518717                  South Africa                       Riots
#
#                 sub_event_type  fatalities  \
# data_id
# 8166147            Armed clash           0
# 8166148                 Attack           5
# 8166410  Violent demonstration           0
# 8166411  Violent demonstration           0
# 8059405                 Attack           2
# ...                        ...         ...
# 7121647           Mob violence           0
# 7966971       Peaceful protest           0
# 7121659            Armed clash           0
# 7518716       Peaceful protest           0
# 7518717  Violent demonstration           0
#
#                                                      notes
# data_id
# 8166147  [june, adf, attacked, military, base, village,...
# 8166148  [june, three, masked, gunman, opened, fire, ci...
# 8166410  [june, worker, pelted, stone, looted, shop, th...
# 8166411  [june, worker, set, tire, fire, blocked, road,...
# 8059405  [june, unidentified, armed, group, attacked, m...
# ...                                                    ...
# 7121647  [june, pdp, supporter, attacked, apc, supporte...
# 7966971  [june, aligned, health, worker, protested, fro...
# 7121659  [june, al, shabaab, militant, launched, attack...
# 7518716  [june, parent, demonstrated, outside, bergvill...
# 7518717  [june, demonstrator, mostly, woman, set, truck...
#
# [33378 rows x 5 columns]

# %%
def remove_stopwords(text):
    words = [w for w in text if w not in stopwords.words('english')]
    return words

# %%
df["notes"] = df["notes"].apply(lambda x: remove_stopwords(x))

# %%
df
# Out:
#                               country                  event_type  \
# data_id
# 8166147  Democratic Republic of Congo                     Battles
# 8166148                         Sudan  Violence against civilians
# 8166410                       Lesotho                       Riots
# 8166411                       Lesotho                       Riots
# 8059405                        Uganda  Violence against civilians
# ...                               ...                         ...
# 7121647                       Nigeria                       Riots
# 7966971                       Tunisia                    Protests
# 7121659                       Somalia                     Battles
# 7518716                  South Africa                    Protests
# 7518717                  South Africa                       Riots
#
#                 sub_event_type  fatalities  \
# data_id
# 8166147            Armed clash           0
# 8166148                 Attack           5
# 8166410  Violent demonstration           0
# 8166411  Violent demonstration           0
# 8059405                 Attack           2
# ...                        ...         ...
# 7121647           Mob violence           0
# 7966971       Peaceful protest           0
# 7121659            Armed clash           0
# 7518716       Peaceful protest           0
# 7518717  Violent demonstration           0
#
#                                                      notes
# data_id
# 8166147  [june, adf, attacked, military, base, village,...
# 8166148  [june, three, masked, gunman, opened, fire, ci...
# 8166410  [june, worker, pelted, stone, looted, shop, th...
# 8166411  [june, worker, set, tire, fire, blocked, road,...
# 8059405  [june, unidentified, armed, group, attacked, m...
# ...                                                    ...
# 7121647  [june, pdp, supporter, attacked, apc, supporte...
# 7966971  [june, aligned, health, worker, protested, fro...
# 7121659  [june, al, shabaab, militant, launched, attack...
# 7518716  [june, parent, demonstrated, outside, bergvill...
# 7518717  [june, demonstrator, mostly, woman, set, truck...
#
# [33378 rows x 5 columns]

# %%
def remove_month(text):
    dates = ['january', 'feburary', 'march','april','may','june','july','august','september','october','november','december']
    words =[w for w in text if w not in dates]
    return words

# %%
df["notes"] = df["notes"].apply(lambda x: remove_month(x))

# %%
df['notes']
# Out:
# data_id
# 8166147    [adf, attacked, military, base, village, kokol...
# 8166148    [three, masked, gunman, opened, fire, civilian...
# 8166410    [worker, pelted, stone, looted, shop, thetsane...
# 8166411    [worker, set, tire, fire, blocked, road, maput...
# 8059405    [unidentified, armed, group, attacked, ministe...
#                                  ...
# 7121647    [pdp, supporter, attacked, apc, supporter, oso...
# 7966971    [aligned, health, worker, protested, front, re...
# 7121659    [al, shabaab, militant, launched, attack, juba...
# 7518716    [parent, demonstrated, outside, bergville, pri...
# 7518717    [demonstrator, mostly, woman, set, truck, alig...
# Name: notes, Length: 33378, dtype: object

# %%
protests_df = df.loc[df['event_type'] == "Protests"]

# %%
protests_df
# Out:
#                               country event_type    sub_event_type  \
# data_id
# 8059413                        Zambia   Protests  Peaceful protest
# 8059671                  South Africa   Protests  Peaceful protest
# 8059418                       Morocco   Protests  Peaceful protest
# 8059426                       Tunisia   Protests  Peaceful protest
# 8059437                       Algeria   Protests  Peaceful protest
# ...                               ...        ...               ...
# 7121353                       Nigeria   Protests  Peaceful protest
# 7121613                       Tunisia   Protests  Peaceful protest
# 7887842  Democratic Republic of Congo   Protests  Peaceful protest
# 7966971                       Tunisia   Protests  Peaceful protest
# 7518716                  South Africa   Protests  Peaceful protest
#
#          fatalities                                              notes
# data_id
# 8059413           0  [doctor, gathered, university, teaching, hospi...
# 8059671           0  [group, blocked, north, south, melmoth, road, ...
# 8059418           0  [member, national, union, unemployed, graduate...
# 8059426           0  [farmer, protested, beja, beja, nord, beja, de...
# 8059437           0  [dozen, aadl, social, housing, program, subscr...
# ...             ...                                                ...
# 7121353           0  [people, umbrella, jac, demonstrated, federal,...
# 7121613           0  [group, contractual, teacher, public, school, ...
# 7887842           0  [resident, kashanje, village, near, mbuhi, pil...
# 7966971           0  [aligned, health, worker, protested, front, re...
# 7518716           0  [parent, demonstrated, outside, bergville, pri...
#
# [11540 rows x 5 columns]

# %%
battles_df = df.loc[df['event_type'] == "Battles"]

# %%
battles_df
# Out:
#                               country event_type sub_event_type  fatalities  \
# data_id
# 8166147  Democratic Republic of Congo    Battles    Armed clash           0
# 8059690                       Somalia    Battles    Armed clash           1
# 8059708                       Somalia    Battles    Armed clash          25
# 8059742                       Somalia    Battles    Armed clash           0
# 8059778                       Somalia    Battles    Armed clash           0
# ...                               ...        ...            ...         ...
# 7887845  Democratic Republic of Congo    Battles    Armed clash           4
# 7887846  Democratic Republic of Congo    Battles    Armed clash           2
# 7887847  Democratic Republic of Congo    Battles    Armed clash           2
# 7887851  Democratic Republic of Congo    Battles    Armed clash           2
# 7121659                       Somalia    Battles    Armed clash           0
#
#                                                      notes
# data_id
# 8166147  [adf, attacked, military, base, village, kokol...
# 8059690  [two, group, government, police, force, clashe...
# 8059708  [government, security, force, sna, clashed, al...
# 8059742  [al, shabaab, militant, attacked, government, ...
# 8059778  [al, shabaab, militant, carried, attack, gover...
# ...                                                    ...
# 7887845  [nyatura, militiaman, clashed, killed, policem...
# 7887846  [ndc, r, rebel, clashed, armed, men, apcls, ny...
# 7887847  [ndc, r, rebel, clashed, armed, men, apcls, ny...
# 7887851  [fardc, clashed, mayi, mayi, militiaman, bulon...
# 7121659  [al, shabaab, militant, launched, attack, juba...
#
# [7448 rows x 5 columns]

# %%
protests_df.to_csv('step2_ACLED_Dataset_END_protests.csv')
battles_df.to_csv('step2_ACLED_Dataset_END_battles.csv')
